# %% [markdown]
# # Fleet Utilization & Operational Efficiency Analysis 🚚📊

# %% [markdown]
# This notebook analyzes fleet performance across **5 regions** between **May 2024 – May 2025**, using 112,568 simulated trips across 200 vehicles.

# %%
import pandas as pd

df = pd.read_csv('data/fleet_utilization_dataset.csv', parse_dates=['start_time','end_time'])
df.head()

# %% [markdown]
# ## Trip Duration Distribution

# %% [markdown]
# ![Trip Duration](images/trip_duration.png)

# %% [markdown]
# ## Mileage Distribution

# %% [markdown]
# ![Mileage](images/mileage_distribution.png)

# %% [markdown]
# ## Idle Time After Trips

# %% [markdown]
# ![Idle Time](images/idle_distribution.png)

# %% [markdown]
# ## Trips by Region

# %% [markdown]
# ![Trips by Region](images/trips_by_region.png)
